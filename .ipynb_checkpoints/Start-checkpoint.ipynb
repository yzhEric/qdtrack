# %% [markdown]
# ## 依赖项安装

# %%
# !python setup.py develop
# Out:
# running develop
# running egg_info
# creating qdtrack.egg-info
# writing qdtrack.egg-info/PKG-INFO
# writing dependency_links to qdtrack.egg-info/dependency_links.txt
# writing requirements to qdtrack.egg-info/requires.txt
# writing top-level names to qdtrack.egg-info/top_level.txt
# writing manifest file 'qdtrack.egg-info/SOURCES.txt'
# reading manifest file 'qdtrack.egg-info/SOURCES.txt'
# writing manifest file 'qdtrack.egg-info/SOURCES.txt'
# running build_ext
# Creating /usr/local/lib/python3.8/dist-packages/qdtrack.egg-link (link to .)
# Adding qdtrack 0.1.0+c5b1047 to easy-install.pth file
#
# Installed /gemini/code
# Processing dependencies for qdtrack==0.1.0+c5b1047
# Searching for lvis
# Reading https://pypi.org/simple/lvis/
# ...
# Best match: lvis 0.5.3
# Processing lvis-0.5.3-py3-none-any.whl
# Installing lvis-0.5.3-py3-none-any.whl to /usr/local/lib/python3.8/dist-packages
# Adding lvis 0.5.3 to easy-install.pth file
#
# ...

# %% [markdown]
# ## 准备数据集

# %%
# !pip install git+https://github.com/bdd100k/bdd100k.git@master

# %%
SET_NAME = 'train' # 训练集标注处理
# !python -m bdd100k.label.to_coco -m det -i bdd100k/labels/det_20/det_{SET_NAME}.json -o data/bdd/labels/det_20/det_{SET_NAME}_cocofmt.json
# !python -m bdd100k.label.to_coco -m box_track -i bdd100k/labels/box_track_20/{SET_NAME} -o data/bdd/labels/box_track_20/box_track_{SET_NAME}_cocofmt.json

# %%
SET_NAME = 'val'  # 验证集标注处理
# !python -m bdd100k.label.to_coco -m det -i bdd100k/labels/det_20/det_{SET_NAME}.json -o data/bdd/labels/det_20/det_{SET_NAME}_cocofmt.json
# !python -m bdd100k.label.to_coco -m box_track -i bdd100k/labels/box_track_20/{SET_NAME} -o data/bdd/labels/box_track_20/box_track_{SET_NAME}_cocofmt.json

# %% [markdown]
# ## 训练

# %%
import os
os.chdir('/gemini/code/configs\\bdd100k')
#os.chdir('/gemini\\data-1\\bdd100k\\images')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In [1], line 2
#       1 import os
# ----> 2 os.chdir('/gemini/code/configs\\bdd100k')
#       3 #os.chdir('/gemini\\data-1\\bdd100k\\images')
#
# FileNotFoundError: [Errno 2] No such file or directory: '/gemini/code/configs\\bdd100k'

# %%
# !python tools/train.py configs/bdd100k/qdtrack-frcnn_r50_fpn_12e_bdd100k_search.py
# Out:
# /usr/local/lib/python3.8/dist-packages/mmcv/__init__.py:20: UserWarning: On January 1, 2023, MMCV will release v2.0.0, in which it will remove components related to the training process and add a data transformation module. In addition, it will rename the package names mmcv to mmcv-lite and mmcv-full to mmcv. See https://github.com/open-mmlab/mmcv/blob/master/docs/en/compatibility.md for more details.
#   warnings.warn(
# 2023-03-08 14:53:39,060 - qdtrack - INFO - Environment info:
# ------------------------------------------------------------
# sys.platform: linux
# Python: 3.8.10 (default, Jun 22 2022, 20:18:18) [GCC 9.4.0]
# CUDA available: True
# CUDA_HOME: /usr/local/cuda
# NVCC: Build cuda_11.3.r11.3/compiler.29920130_0
# GPU 0: B3.gpu.small
# GCC: gcc (Ubuntu 9.4.0-1ubuntu1~20.04.1) 9.4.0
# PyTorch: 1.12.1+cu113
# PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201402
# ...
